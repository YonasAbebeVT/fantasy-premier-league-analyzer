# %%
import pandas as pd

# %%
df = pd.read_html("premier-league.html", 
                  attrs={"id": "stats_standard"})[0]

# %%
df.columns = ['_'.join(col).strip() for col in df.columns.values]

# %%
df.head()
# Out:
#   Unnamed: 0_level_0_Rk Unnamed: 1_level_0_Player Unnamed: 2_level_0_Nation  \
# 0                     1                Max Aarons                   eng ENG
# 1                     2         Joshua Acheampong                   eng ENG
# 2                     3               Tyler Adams                    us USA
# 3                     4          Tosin Adarabioyo                   eng ENG
# 4                     5             Simon Adingra                    ci CIV
#
#   Unnamed: 3_level_0_Pos Unnamed: 4_level_0_Squad Unnamed: 5_level_0_Age  \
# 0                     DF              Bournemouth                     24
# 1                     DF                  Chelsea                     18
# 2                     MF              Bournemouth                     25
# 3                     DF                  Chelsea                     26
# 4                  FW,MF                 Brighton                     22
#
#   Unnamed: 6_level_0_Born Playing Time_MP Playing Time_Starts  \
# ...

# %%
df.to_csv("premier-league-stats.csv", index=False)
